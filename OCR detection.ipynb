# %%
# !pip install pytesseract

# %%
import cv2
import matplotlib.pyplot as plt
import pytesseract as pyt

# %%
pyt.pytesseract.tesseract_cmd = r"C:\Program Files (x86)\Tesseract-OCR\tesseract.exe"

# %%
img = cv2.imread("license_plate.jpeg")
plt.imshow(img)

# %%
text = pyt.image_to_string(img, lang= "eng")
text
# Out:
# ''

# %%
plt.imshow(img[150:250, 125:350,:])

# %%
cv2.imwrite("license.jpg",img[150:250, 125:350,:])
# Out:
# True

# %%
text = pyt.image_to_string(img[150:250, 125:350,:])
text
# Out:
# ''

# %%
import os

# %%
text = pyt.image_to_string('Capture.JPG')
print(text)
# Out:
# i., :4 -2 A .
#
# 2.’ ~“.-» '41:-.~..”adI '!.::‘:::'«r'-i.~&~. ' inn.‘ iv; 5 h; .-+ » =‘
# _‘ Q Search the web
#
#
#
# , gm
#
#
#
#
#
# Discover Folluwing News Sports Play Money Gaming Weather waich Shopping Healih Travel Traffic Autos Leaming  -‘
#
#
#
#
# -|miaTmay_5h Inﬁmesnow-7h
#
# . . . . Virat Kohli Breaks Coach
# Yvlp-ro files com-plaint ag-ainst ex-ernployee for Rahul DraVid.S M assive
# ]0lnll'Ig competitor Cognizant, here IS what happened Record in south Africa_,__
# (5 30 Q l;] .- ............. .. “ﬁnding 45 62 Q C] ,,.,,e,,di,,g
#
# O Top smnes
#
# [4 Times Now 44\
# Breaking News | Bomb Scale At Israel
#
#
#
# . . «— \‘ ”
# Embasy in Delhi. NIA onieials on Spot , E-it;
# |n Times Now in ‘ ""
# ‘Rat in Hell‘: Donald Trump's Angry
#
# chnshm MesageTalge1s'Cmo|red J... '"'"'°'"°" , ‘ '
#
# Q Himusiannmes-id l
# I Hmdum was ah Move on End-of-Year scores. . 7 I _ .
# D" _V, hm‘ Prabhas Salaar, Shah Rukh K ans Dunkl claim top spot:
# WF|p s. Ines ogattnnaw remm Id _d b ff_ K
# ...
